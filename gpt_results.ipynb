# %%
import pandas as pd

# %%
use_narrations = True
cot = "_nocot" if use_narrations else ""
df = pd.read_csv(f"gpt4o_{use_narrations}_test_min4{cot}.csv")
df.head(3)
# Out:
#                                                query correct_answer  \
# 0     Query: Remember what I did to this engine body         Memory
# 1  Query: How long should I cook this dough for? ...      Assistant
# 2  Query: Show me a video tutorial on how to make...   Instructions
#
#          pred_answer  correct
# 0             Memory     True
# 1          Assistant     True
# 2  Multimodal search    False

# %%
print(f"{df.correct.mean():.2%}")
# Out:
# 80.26%

# %%
use_narrations = False
cot = "_nocot" if use_narrations else ""
df = pd.read_csv(f"gpt4o_{use_narrations}_test_min4{cot}.csv")
print(f"{df.correct.mean():.2%}")
# Out:
# 76.13%
